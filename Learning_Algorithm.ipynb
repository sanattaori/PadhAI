# %% [markdown]
# <a href="https://colab.research.google.com/github/sanattaori/PadhAI/blob/master/Learning_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# display image
from IPython.display import Image

#Image('drive/My Drive/sc/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Learning by guessing

# %%
Image('drive/My Drive/sc/intro_la.png')

# %% [markdown]
# for multidimensions it is inefficient to work with guess work

# %% [markdown]
# ### Aim: our loss function steadly decreases

# %%
Image('drive/My Drive/sc/lossfn.png')

# %% [markdown]
# ### Computing delta w

# %%
Image('drive/My Drive/sc/delta_w.png')

# %% [markdown]
# ## Taylor Series

# %%
Image('drive/My Drive/sc/taylor.png')

# %% [markdown]
# ###  taylor series for scalar vs vector

# %%
Image('drive/My Drive/sc/taylor_vector.png')

# %% [markdown]
# ### partial derivatives and gradients

# %%
#calculating gradients

# %%
Image('drive/My Drive/sc/gradients.png')

# %%
Image('drive/My Drive/sc/compute_delta_w.png')

# %%
def I(image_name):
  return Image('drive/My Drive/sc/'+image_name+'.png')

# %%
I('new_loss')

# %%
I('angle')

# %%
I('grad_dir')

# %% [markdown]
# ### Computing Partial Derivatives

# %%
# sum rule
I('sum_rule')

# %%
I('compute_pd')

# %%
I('final_comp')
