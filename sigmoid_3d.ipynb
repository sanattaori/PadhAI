# %% [markdown]
# <a href="https://colab.research.google.com/github/sanattaori/PadhAI/blob/master/sigmoid_3d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sigmoid 3d

# %%
import numpy as np
from mpl_toolkits import mplot3d

# %%
import matplotlib.pyplot as plt

# %%
def sigmoid_3d(x1,x2,w1,w2,b):
  return 1/(1+np.exp(-(w1*x1 + w2*x2 +b)))

# %%
X1 = np.linspace(-10,10,100)
X2 = np.linspace(-10,10,100)

XX1, XX2 = np.meshgrid(X1,X2)

# %%
print(XX1.shape,XX2.shape)
# Out:
# (100, 100) (100, 100)

# %%
w1 = .5
w2 = .5
b = 0
Y = sigmoid_3d(XX1,XX2,w1,w2,b)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(XX1, XX2, Y, cmap='viridis')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(XX1, XX2, Y, cmap='viridis')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.view_init(30,0)

# %%
degree = 166  #@param {type: "slider", min: 0, max: 360}

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(XX1, XX2, Y, cmap='viridis')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.view_init(30,degree)
