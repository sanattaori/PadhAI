# %% [markdown]
# # Complex Functions

# %% [markdown]
# ## Why do we need complex functions?

# %%
I('smooth complex function.png')

# %%
I('sigmoid unusable.png')

# %% [markdown]
# ## Modeling Complex Relations

# %%
I('nn.png')

# %%
I('combinations of neurons.png')
