# %% [markdown]
# <a href="https://colab.research.google.com/github/sanattaori/PadhAI/blob/master/Cross_Entropy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# display image
from IPython.display import Image

#Image('drive/My Drive/sc/')

def I(image_name):
  return Image('drive/My Drive/sc/'+image_name)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Sigmoid Neuron and Cross Entropy

# %%
I('min_fwb.png')

# %% [markdown]
# ## Loss function

# %%
I('loss_fn.png')

# %%
I('simplified loss function.png')

# %%
I('learning algorithm.png')

# %%
I('Computing partial derivatives.png')

# %%
#changes for cross entropy
I('cross entropy la.png')
