# %% [markdown]
# <a href="https://colab.research.google.com/github/sanattaori/PadhAI/blob/master/Vectors_and_Matrices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ***ScreenCaps from Deep learning course of [One Fourth Labs](https://padhai.onefourthlabs.in/)***

# %% [markdown]
# # Vectors

# %% [markdown]
# ### Magnitude of vector

# %%
Image('drive/My Drive/sc/One Fourth Lab.png')

# %% [markdown]
# ### Magitude of N-dimensional vector

# %%
Image('drive/My Drive/sc/One Fourth Labs.png')

# %% [markdown]
# ### Operations on vectors

# %%
Image('drive/My Drive/sc/One Fourth Labs.png')

# %%
import numpy as np

# %%
u = np.array([1,-1,2,3,4])
v = np.array([3,5,-2,1,0])

# %%
np.dot(u,v)
# Out:
# -3

# %%
Image('drive/My Drive/sc/dot product.png')

# %% [markdown]
# ### Unit Vector

# %% [markdown]
# Simplest unit vectors are the Vector in direction of coordinate axis.

# %%
Image('drive/My Drive/sc/unit vector.png')

# %% [markdown]
# ***Projection of one vector onto another***

# %%
Image('drive/My Drive/sc/projection.png')

# %% [markdown]
# ### Angle between two vectors

# %%
Image('drive/My Drive/sc/angle_bw_vectors.png')

# %% [markdown]
# ***Orthogonal Vectors***

# %% [markdown]
# The vectors in which dot product of two vectors is 0 then the angle between them is 90

# %%
Image('drive/My Drive/sc/orthogonal.png')

# %% [markdown]
# # Matrices

# %% [markdown]
# Collection of row and column vector

# %% [markdown]
# *Multiplying a vector by a matrix*

# %%
Image('drive/My Drive/sc/mul_matrix_vector.png')
